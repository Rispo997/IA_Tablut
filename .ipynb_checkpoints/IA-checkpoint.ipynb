# %%
import numpy
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn import svm

import m2cgen as m2c

# %%
col_names = []
for i in range(9):
  for j in range(9):
    col_names.append(str(i)+","+str(j)+"(black)")
    col_names.append(str(i)+","+str(j)+"(white)")
    col_names.append(str(i)+","+str(j)+"(king)")
col_names.append("Player")
col_names.append("Evaluation")
data = pd.read_csv("dataset.csv",names=col_names)
#deleting drawing
#data = data[data['Evaluation'] != 0]
#train just white
#data = data[data['Player'] == 1]
#train just black
#data = data[data['Player'] == 0]
#data = data[data['Evaluation'] > 0]
#print(data.count)
#nothing -> train everybody
X = data.drop("Evaluation",axis=1)
Y = data["Evaluation"]
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,Y,random_state=1)
#regression
#reg = LinearRegression()
#model = reg.fit(Xtrain,Ytrain)
#predictions = reg.predict(Xtest)
#test = mean_absolute_error(Ytest, predictions)
#predictions = reg.predict(Xtrain)
#train = mean_absolute_error(Ytrain, predictions)
#print("Regression:")
#print(train)
#print(test)
#support vector linear regression
#svr = svm.SVR()
svr = svm.LinearSVR(max_iter=15000)
model = svr.fit(Xtrain,Ytrain)
predictions = svr.predict(Xtest)
test = mean_absolute_error(Ytest, predictions)
predictions = svr.predict(Xtrain)
train = mean_absolute_error(Ytrain, predictions)
print("Support vector regression:")
print(train)
print(test)
#print(svr.coef_ )
#print(len(svr.coef_ ))

print(m2c.export_to_java(svr))
# Out:
# Support vector regression:
# 0.015207546530178528
# 0.009237248754044608
# [ 5.34625380e-07 -2.15136125e-06  0.00000000e+00  4.93009583e-06
#   8.47085234e-07  0.00000000e+00 -9.26899146e-07  1.89006946e-06
#   7.81867009e-01  6.69486728e-08  0.00000000e+00  0.00000000e+00
#  -4.95814905e-06  0.00000000e+00  0.00000000e+00  2.03013471e-07
#   0.00000000e+00  0.00000000e+00  4.24685482e-06  2.61267285e-06
#   7.81868140e-01 -1.01632634e-06  3.26366158e-08  7.81895315e-01
#  -4.01177632e-06 -4.29128856e-07  0.00000000e+00  4.04462548e-06
#  -2.38251050e-06  7.81250404e-01  2.67808337e-06  3.41594383e-06
#   0.00000000e+00 -4.65599238e-07  1.96679968e-06 -2.18136745e-01
#   5.52807794e-06 -1.52009269e-06 -2.18122797e-01 -2.10880712e-06
#   0.00000000e+00  0.00000000e+00  3.20484715e-06 -1.57063693e-06
#  -2.18111746e-01 -2.48653699e-06 -2.07861378e-06 -2.18132457e-01
#  -6.88002273e-08  3.98339331e-06  0.00000000e+00  3.27418846e-06
#  -4.28157758e-06  0.00000000e+00 -3.59148585e-07 -3.67851979e-06
#   7.81866198e-01  3.14933841e-07  2.05695385e-07 -2.18117750e-01
#   6.30365921e-07 -7.41928891e-07 -2.18131838e-01 -1.14223686e-06
#  -1.01326101e-06 -2.18135559e-01  3.16040277e-06  2.81009142e-06
#  -2.18141598e-01 -9.20347239e-07 -1.19325243e-06 -2.18126914e-01
#   3.43829258e-06 -2.42690232e-06 -2.18128955e-01 -1.19783383e-06
#   2.22864510e-06 -2.18132383e-01 -3.61442857e-06 -4.18145662e-06
#   7.81876360e-01 -4.40238083e-06  0.00000000e+00  0.00000000e+00
#   1.00370729e-05  3.00498871e-06 -1.00000000e+00  5.31304267e-07
#   2.49313838e-06 -2.18135909e-01 -7.42645381e-06  2.67050812e-06
#  -2.18140026e-01  1.38780143e-06 -3.07452923e-06 -2.18138040e-01
#  -3.59868085e-06 -5.21017871e-06 -2.18134829e-01 -1.64643596e-06
